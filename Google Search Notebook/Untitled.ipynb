# %%
from googlesearch import search

# %%
query = "apple iphone news 2019"

# %%
my_results_list = []
for i in search(query,        # The query you want to run
                tld = 'com',  # The top level domain
                lang = 'en',  # The language
                num = 10,     # Number of results per page
                start = 0,    # First result to retrieve
                stop = None,  # Last result to retrieve
                pause = 2.0,  # Lapse between HTTP requests
               ):
    my_results_list.append(i)
    print(i)
# Out:
# https://www.macrumors.com/roundup/iphone-11/
# https://www.pocket-lint.com/phones/news/apple/148464-apple-iphone-12-pro-max-release-date-specs-features-news
# https://www.apple.com/sg/newsroom/archive/iphone/
# https://www.businessinsider.com/new-iphones-from-apple-2019-rumors-features-specs-2019-3
# https://www.tomsguide.com/reviews/iphone-11
# https://www.techradar.com/sg/reviews/iphone-11-review
# https://www.theverge.com/2019/9/5/20850075/apple-iphone-11-plus-max-camera-rumors-leaks-event-2019
# https://www.theverge.com/2019/9/3/20838809/apple-iphone-event-2019-rumors-news-updates
# https://www.wired.com/story/everything-apple-announced-sept-2019/
# https://www.macworld.co.uk/news/iphone/new-iphone-11-pro-release-date-3665250/
# https://www.forbes.com/sites/gordonkelly/2019/06/18/apple-new-iphone-2020-update-release-camera-upgrade-iphone-xs-max-xr/
# https://www.digitaltrends.com/mobile/iphone-11-news-specs-release/
# ...

# %%
from googleapiclient.discovery import build   #Import the library

# %%
api_key = "AIzaSyCrf6qu1p0gDoXad38PkY6yscorokOwTx4"
cse_id = "013098857068574615745:eekb3f72ak4"


def google_query(query, api_key, cse_id, **kwargs):
    query_service = build("customsearch", 
                          "v1", 
                          developerKey=api_key
                          )  
    query_results = query_service.cse().list(q=query,    # Query
                                             cx=cse_id,  # CSE ID
                                             **kwargs    
                                             ).execute()
    return query_results['items']

my_results_list = []
my_results = google_query("apple iphone news 2019",
                          api_key, 
                          cse_id, 
                          num = 10
                          )
for result in my_results:
    my_results_list.append(result['link'])
    print(result['link'])
# Out:
# https://www.google.com/appserve/mkt/p/AFnwnKWVmpmN2s87U97LQw9fMjeWBvMqsLxSqqzyajG46deDl5tP-36mOSrVMnmePcEtSvvdt-i36gZd9fu1vDhXOBtPHVBLB4z7tDpY1nVo8SiGIFsduqTSQAVIQuo9Pxk2Do3DgPNnS8MmQeGAmOnDa1nO2Vjgt68B_wfHkjU8o6G2cx_JA2Rs3u9PS9_TApUC2FxnBwyUsnCm2zJAPCecQDqG2Es
# https://www.google.com/appserve/mkt/p/AFnwnKVqvuvJnC1m33xHSY_kzT0N11s_TzJmvB9FXTOycf77f02IVoBrZGXkjzffi4rQVcoDaUn-F9y4jzO7s8SXoYgcUjRaiC6nulRCo_P23Qa-kF1W9pFaP1YA8PklNdf3__P8Zvt8WXVA774SE0QL5xEzTyfAGuGlOstp13wVz-HqLdrL3hYzzCf_gCxSJojGNAt7C6DGWrlQTLdJpA
# https://www.google.com/appserve/mkt/p/AFnwnKUFkzpZtM6WLKNMQ9TheZ-_d2fE5pYpWOLLamo8QvqXCr2CGc1BlahAXCkQnzeRpwYPGOfb5idF3OxRfLKbGVbJD0US-dhPrcGSlS-gjICiZIgtL4bxh2z6CBRYoD9CDKe7VDzJnD7LNL2PgTBNc6U1nAOOOUQbXq25Cy5vMxMgHh25xxWlugRz3cRPGj5rNhd-66rCGeIiZ64sV7MVverbDkf9mjLQdq6FgcC5
# ...

# %%
from googleapiclient.discovery import build
import pprint

my_api_key = "AIzaSyCrf6qu1p0gDoXad38PkY6yscorokOwTx4"
my_cse_id = "013098857068574615745:eekb3f72ak4"

def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res['items']

results = google_search(
    'stackoverflow site:en.wikipedia.org', my_api_key, my_cse_id, num=10)
for result in results:
    pprint.pprint(result)
# Out:
# {'cacheId': 'SYLF4bZFF-oJ',
#  'displayLink': 'en.wikipedia.org',
#  'formattedUrl': 'https://en.wikipedia.org/wiki/Stack_Overflow',
#  'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/<b>Stack_Overflow</b>',
#  'htmlSnippet': '<b>Stack Overflow</b> is a question and answer site for '
#                 'professional and enthusiast <br>\n'
#                 'programmers. It is a privately held website, the flagship '
#                 'site of the Stack <br>\n'
#                 'Exchange&nbsp;...',
#  'htmlTitle': '<b>Stack Overflow</b> - Wikipedia',
#  'kind': 'customsearch#result',
#  'link': 'https://en.wikipedia.org/wiki/Stack_Overflow',
#  'pagemap': {'cse_image': [{'src': 'https://upload.wikimedia.org/wikipedia/en/f/fa/Stack_Overflow_homepage%2C_Feb_2017.png'}],
#              'cse_thumbnail': [{'height': '153',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQkbgSLaGmvoICqsJiEwrPwpyLxwrgp7tyBGPs0E1zJO6kYZSjnyvvfXFht',
# ...

# %%
results = google_search(
    'Junction 8 Macs', my_api_key, my_cse_id, num=10)

# %%
for result in results:
    pprint.pprint(result)
# Out:
# {'cacheId': 'JFu5h9Fou8IJ',
#  'displayLink': 'www.capitaland.com',
#  'formattedUrl': "https://www.capitaland.com/sg/malls/junction8/en/stores/mcdonald's.html",
#  'htmlFormattedUrl': 'https://www.capitaland.com/sg/malls/<b>junction8</b>/en/stores/mcdonald&#39;s.html',
#  'htmlSnippet': 'Sink your teeth into local favourites like McSpicy or '
#                 'McNuggets with our signature <br>\n'
#                 'Curry Sauce, or go for the all-time favourites like Big '
#                 '<b>Mac</b> or Filet-O-Fish.',
#  'htmlTitle': 'McDonald&#39;s | Fast Food | Food &amp; Beverage | <b>Junction '
#               '8</b>',
#  'kind': 'customsearch#result',
#  'link': "https://www.capitaland.com/sg/malls/junction8/en/stores/mcdonald's.html",
#  'pagemap': {'cse_image': [{'src': 'https://www.capitaland.com/content/dam/capitaland-media-library/retail/Singapore/Singapore/Junction%208/tenant_storefront/mcd-sf.png.transform/cap-midres/image.png'}],
# ...

# %%
for result in results:
    pprint.pprint(result['link'])
# Out:
# "https://www.capitaland.com/sg/malls/junction8/en/stores/mcdonald's.html"
# 'https://www.livermoreschools.org/Page/172'
# 'https://coonscornercompany.com/macs-booster'
# 'https://www.facebook.com/McDonalds.BishanJunction8'
# 'https://www.cms.gov/Medicare/Medicare-Contracting/Medicare-Administrative-Contractors/Who-are-the-MACs-A-B-MAC-Jurisdiction-8-J8'
# 'https://www.yelp.com/biz/macs-market-essex-junction'
# 'https://www.gjcity.org/residents/parks-recreation/special-events/southwest-arbor-fest/'
# 'https://www.junctioncitychamber.org/about-mac.html'
# 'https://store.simplymac.com/pages/grand-junction-colorado'
# 'https://www.junctioncitychamber.org/mac-breakfast.html'

# %%
# Python program to get a set of  
# places according to your search  
# query using Google Places API 
  
# importing required modules 
import requests, json 
  
# enter your api key here 

  
# url variable store url 
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
  
# The text string on which to search 
query = input('Search query: ') 
  
# get method of requests module 
# return response object 
r = requests.get(url + 'query=' + query +
                        '&key=' + api_key) 
  
print(r)
# json method of response object convert 
#  json format data into python format data 
x = r.json() 
  
# now x contains list of nested dictionaries 
# we know dictionary contain key value pair 
# store the value of result key in variable y 
y = x['results'] 
  
    
# keep looping upto length of y 
for i in range(len(y)): 
      
    # Print value corresponding to the 
    # 'name' key at the ith index of y 
    print(y[i]['name'])
# Out:
# Search query: AMK MOOKATA
# <Response [200]>
# Bangkok Street Mookata - Ang Mo Kio

# %%
x
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': '421 Ang Mo Kio Ave 10, #01-1149, Singapore 560421',
#    'geometry': {'location': {'lat': 1.3654879, 'lng': 103.8530996},
#     'viewport': {'northeast': {'lat': 1.366750979892722,
#       'lng': 103.8545020298927},
#      'southwest': {'lat': 1.364051320107278, 'lng': 103.8518023701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '6dc41bb8e8cb01ff8521d0be913818d3c04e6055',
#    'name': 'Bangkok Street Mookata - Ang Mo Kio',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112733054559480791579">Angelina Tan</a>'],
#      'photo_reference': 'CmRaAAAAii2kdmfY55w8VkRw6vaFnX1fcDfEKINt3Hzttail9vjkkaXO_AUCwxeIBJoJsmj_5WPo3WVtQpo8pP7nPgbzzIe9w8dsz2sqBVY0qrt4wtJz0UO4CWK3ovsFBmT4MkSvEhCYyaXfTJhBbb6LX6p20xoIGhTeTol3AZ406IcgSYat3ObCtx57ow',
# ...

# %%
# PHOTO REQUEST
import requests, json 

my_api_key = "AIzaSyCrf6qu1p0gDoXad38PkY6yscorokOwTx4"
photoreference = "CmRaAAAAtg_zKd7Y8jPb-3XlKw2PSmgUCvOcRVkp0LzcrGpSgQEe5UdOiLDl1Rhbpv2gOfEJbCJdhiaUkThiUzrke4ptbCswbJ_ypXTp4kRwG6Qp7rMD7yK4BZoWOY79Y5fDj5BQEhDZKjuRbA-cWu3jUHHd39sRGhQkkIhF13fI1g8u_8rzaTI1VMNKkQ"
maxwidth= "400"

url = "https://maps.googleapis.com/maps/api/place/photo?"
r = requests.get(url + 'maxwidth=' + maxwidth +
                 '&photoreference=' + photoreference
                +'&key=' + my_api_key)

print (r)
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-2-52b7ec8d97cc> in <module>
# ----> 1 r.json()
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~\AppData\Local\Programs\Python\Python38\Lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ...

# %%
r
# Out:
# <Response [200]>

# %%
from IPython.display import Image, display
display(Image(r.content))

# %%
type(r)
# Out:
# requests.models.Response
